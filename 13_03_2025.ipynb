# %% [markdown]
# <a href="https://colab.research.google.com/github/teja82/Assignments/blob/main/13_03_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -U -q"google-generativeai>=0.72"
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -g

# %%
import google.generativeai as genai
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model =genai.GenerativeModel('models/gemini-2.0-flash')
response =model.generate_content("Please give me python code tosort a list.")
print(response.text)
# Out:
# ```python
# # Method 1: Using the built-in `sorted()` function (returns a new sorted list)
#
# def sort_list_new(my_list):
#   """
#   Sorts a list using the built-in `sorted()` function, creating a new sorted list.
#
#   Args:
#     my_list: The list to be sorted.
#
#   Returns:
#     A new list containing the sorted elements of the input list.
#   """
#   return sorted(my_list)
#
# # Example usage:
# my_list = [3, 1, 4, 1, 5, 9, 2, 6]
# sorted_list = sort_list_new(my_list)
# print("Original list:", my_list)
# print("Sorted list:", sorted_list)
# print("Original List after: ",my_list)
#
#
# # Method 2: Using the `list.sort()` method (sorts the list in-place)
#
# def sort_list_in_place(my_list):
#   """
#   Sorts a list in-place using the `list.sort()` method.  The original list is modified.
#
#   Args:
#     my_list: The list to be sorted.
#
#   Returns:
#     None (the list is modified directly).
#   """
#   my_list.sort()  # Sorts the list in place
# ...

# %%
from google import genai
from google.genai import types
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
import PIL.Image
from IPython.display import display, Markdown
img=PIL.Image.open('image1.jpg')
response=model.generate_content(["Suggest similar products to this one.",img],stream=True)
response.resolve()
display(img)
Markdown(response. text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=407x377>
# Here are some products that are similar to the ones in the image:
#
# *   **Sony WH-1000XM5:** These are high-end noise-canceling headphones known for excellent sound quality and comfortable design.
#
# *   **Bose QuietComfort 45:** A popular option for noise cancellation and overall sound performance.
#
# *   **Sennheiser Momentum 4 Wireless:** These focus on sound quality with a stylish design.
#
# *   **Anker Soundcore Life Q30:** A budget-friendly option that offers good noise cancellation and features for the price.
#
# *   **JBL Tune 770NC:** Another good value choice for active noise cancellation and bass-heavy sound profiles.

# %%
import PIL.Image
image_path='invoice.jpg'
image=PIL.Image.open(image_path)
response=model.generate_content(['Extract the price from the image.',image])
print(response.text)
# Out:
# Here are the prices extracted from the image:
#
# *   $10,00
# *   $10,00
# *   $10,00
# *   $10,00
# *   $10,00
# *   $100.00
# *   $100.00

# %%
response=model.generate_content(['Extract the price, currency, and any discounts from the image.',image])
print(response.text)
# Out:
# Here's the extracted information from the image:
#
# *   **Price:** $10.00 (per item), $100.00 (Sub Total), $100.00 (Grand Total)
# *   **Currency:** $ (Dollar)
# *   **Discounts:** There is a tax of 10%.

# %%
from PIL import Image
image_path='bicycle.jpg'
image=Image.open(image_path)
#image=PIL.Image.open(image_path)
response=model.generate_content(['Identify all objects present in the image.',image])
print(response.text)
# Out:
# Here are the objects identified in the image:
#
# *   **People:** Two men riding bicycles, one man sitting in a chair.
# *   **Bicycles:** Two bicycles
# *   **Motorcycle:** One motorcycle parked in the background
# *   **Buildings:** Buildings with windows and closed shutters
# *   **Chairs:** Chairs inside the building
# *   **Vegetation:** Grass
# *   **Water Bottles:** attached to the bikes
# *   **Road:** Wet road surface
# *   **Beverages:** Displayed in the storefront rack

# %%
image=Image.open('image.jpg')
response=model.generate_content(['List all objects in this image and count how many of each are present.',image])
print(response.text)
# Out:
# Here's a breakdown of the objects in the image and their counts:
#
# *   **Eggs**: 3
# *   **Banana**: 1
# *   **Olives**: 2
# *   **Fries**: 1 container of fries
# *   **Burger**: 1
# *   **Hot dog**: 1
# *   **Apple**: 1
# *   **Carrots**: 2
# *   **Tomatoes**: 5
# *   **Watermelon**: 1 slice
# *   **Milk**: 1 bottle
# *   **Flour**: 1 bag
# *   **Salt**: 1 shaker
# *   **Sugar**: 1 container
# *   **Jam**: 1 jar
# *   **Meat**: 2 pieces
# *   **Rice**: 1 pan
# *   **Honey**: 1 jar
# *   **Tea**: 1 cup
# *   **Cheese**: 1 slice

# %%
pip install youtube-transcript-api pytube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi
def get_youtube_transcript(video_url):
  """Fetches the transcript of a YouTube video. """
  video_id = video_url.split("v=") [1].split("&")[0] # Extract video ID
  transcript = YouTubeTranscriptApi.get_transcript(video_id)
  full_text = " ".join([t["text"] for t in transcript])
  return full_text
# Example Usage
video_url = "https://www.youtube.com/watch?v=unYDoA8QGH0&list=PLWEpztHwA4ZT2Q1HC74oIz4MsawcvE-QX"
video_transcript = get_youtube_transcript(video_url)
print("Transcript:\n", video_transcript[:500]) # Show first 500 characters
# Out:
# Transcript:
#  hi guys today I'm going to introduce you what is machine learning uh these are my presentation content what is machine learning what are the different applications of machine learning different types of machine learning and how to build a machine learning system or model then various kinds of algorithms and later on in this series we are going to take a Hands-On you know case studies or doing programming for various kinds of up algorithms so what is machine learning so machine learning is nothin

# %%
def summarize_video(text):
    """Summarizes the YouTube video transcript using Gemini AI."""
    prompt = f"Summarize the following YouTube video transcript:\n\n{text}"
    response = model.generate_content(prompt)
    return response.text
summary = summarize_video(video_transcript)
print("Summary:\n", summary)
# Out:
# Summary:
#  This YouTube video provides a beginner-friendly introduction to Machine Learning (ML). Here's a summary:
#
# **Core Concepts:**
#
# *   **What is Machine Learning?** Learning from data (training data/experience) to build systems that improve performance on a task without explicit programming. The goal is to create a model that can predict future events.
# *   **Applications:** ML is widely used in various domains including speech recognition (Siri, Google Assistant), web search, recommendation systems, computer vision, information retrieval, and fraud detection.
# *   **Types of Machine Learning:**
#     *   **Supervised Learning:** Data is labeled (outcome is known).
#         *   **Classification:** Predicting a category (e.g., spam/not spam).
#         *   **Regression:** Predicting a continuous value (e.g., salary, age).
#     *   **Unsupervised Learning:** Data is unlabeled, used to explore data structure (e.g., clustering, dimensionality reduction).
# ...
